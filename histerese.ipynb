# %%
import pandas as pd
import matplotlib.pyplot as plt

laminado = pd.read_table('LFII-histerese_teste_3.txt',decimal=',')
macico = pd.read_table('LFII-histerese_teste_4.txt', decimal=',')

# %%
plt.figure(figsize=(5.5,4))
plt.plot(macico['Corrente I/A']*258.62,macico['Densidade de f BB/mT'],'o',markersize =1, )
plt.grid(visible=True)
plt.ylabel('B (mT)')
plt.xlabel('H (A/m)')
# Out:
# Text(0.5, 0, 'H (A/m)')

# %%
plt.figure(figsize=(5.5,4))

plt.plot(laminado['Corrente I/A']*245.9,laminado['Densidade de f BB/mT'],'o',markersize =1, )
plt.grid(visible=True)
plt.ylabel('B (mT)')
plt.xlabel('H (A/m)')
# Out:
# Text(0.5, 0, 'H (A/m)')
